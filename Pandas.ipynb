# %% [markdown]
# #Pandas Nedir ?

# %%
# Pandas açık kaynaklı ve ücretsiz veri(bilgi) işleme, manipüle etme, temizleme vb. işlemleri yapabileceğimiz oldukça efektik bir kütüphanedir.
# Pandas kütüphanesi NumPy kütüphanesi üzerine kurulmuş bir kütüphanedir.
# Pandas elimizdeki veriyi(bilgiyi) şekillendirip işlememize ve veriden ANLAMLI SONUÇLAR çıkarmamıza olanak sağlar.
# Pandas kütüphanesinin temel elemanları Series ve DataFrame'dir.
# Series ve DataFrame nesnelerini excel tabloları gibi düşünebiliriz.

# %% [markdown]
# #Pandas'ı Import Etme

# %%
# !!pip install pandas
# Out:
# ['Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.2.2)',
#  'Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)',
#  'Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)',
#  'Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)',
#  'Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)',
#  'Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)']

# %% [markdown]
# # Series Oluşturma

# %%
# import pandas
import pandas as pd

# %%
my_data = ['Emincan' , 'Alper' , 'Burak' , 'Dilara' , 'Zeynep']
my_data
# Out:
# ['Emincan', 'Alper', 'Burak', 'Dilara', 'Zeynep']

# %%
pd.Series(my_data)
# Out:
# 0    Emincan
# 1      Alper
# 2      Burak
# 3     Dilara
# 4     Zeynep
# dtype: object

# %%
my_data = [1905 , 1903 , 1907, 1922]
my_idx = ['Galatasaray' , 'Beşiktaş' , 'Fenerbahçe', "Konyaspor" ]

# %%
pd.Series(my_data, my_idx)
# Out:
# Galatasaray    1905
# Beşiktaş       1903
# Fenerbahçe     1907
# Konyaspor      1922
# dtype: int64

# %%
pd.Series(data= my_data, index= my_idx, name = "yıl")
# Out:
# Galatasaray    1905
# Beşiktaş       1903
# Fenerbahçe     1907
# Konyaspor      1922
# Name: yıl, dtype: int64

# %%
my_dict = {
    'Emincan' : 26,
    'Kaan' : 23,
    'Ayşe' : 21,
    'Deniz' : 29
    }

# %%
my_dict
# Out:
# {'Emincan': 26, 'Kaan': 23, 'Ayşe': 21, 'Deniz': 29}

# %%
pd.Series(data = my_dict)
# Out:
# Emincan    26
# Kaan       23
# Ayşe       21
# Deniz      29
# dtype: int64

# %%
# Soru : İstanbul 15.4 , İzmir 4.3 , Ankara 5.6 , Bursa 3 şeklinde seri oluşturun. Hem liste göndererek,
# hem de dictionary göndererek iki yöntemle de yapın.

# %%
my_data = [15.4 , 4.3, 5.6, 3]
my_idx = ['İstanbul' , 'İzmir' , 'Ankara' , 'Bursa']
pd.Series(my_data , my_idx)
# Out:
# İstanbul    15.4
# İzmir        4.3
# Ankara       5.6
# Bursa        3.0
# dtype: float64

# %%
my_dict = {
    'İstanbul' : 15.4,
    'İzmir' : 4.3,
    'Ankara': 5.6,
    'Bursa' : 3
}
pd.Series(my_dict)
# Out:
# İstanbul    15.4
# İzmir        4.3
# Ankara       5.6
# Bursa        3.0
# dtype: float64

# %% [markdown]
# # Serilerde İşlemler

# %%
q1 = {'Japan': 80, 'China' : 450 , 'Turkey': 150 , 'India' : 200 }
q2 = {'Japan': 90, 'China' : 420 , 'Turkey': 230 , 'India' : 195 }

# %%
sales_q1 = pd.Series(q1)
sales_q2 = pd.Series(q2)

# %%
sales_q1
# Out:
# Japan      80
# China     450
# Turkey    150
# India     200
# dtype: int64

# %%
sales_q2
# Out:
# Japan      90
# China     420
# Turkey    230
# India     195
# dtype: int64

# %%
sales_total = sales_q1 + sales_q2
sales_total
# Out:
# Japan     170
# China     870
# Turkey    380
# India     395
# dtype: int64

# %%
sales_total.index
# Out:
# Index(['Japan', 'China', 'Turkey', 'India'], dtype='object')

# %%
sales_total.keys()
# Out:
# Index(['Japan', 'China', 'Turkey', 'India'], dtype='object')

# %%
sales_total.values
# Out:
# array([170, 870, 380, 395])

# %%
sales_total
# Out:
# Japan     170
# China     870
# Turkey    380
# India     395
# dtype: int64

# %%
sales_total * 2
# Out:
# Japan      340
# China     1740
# Turkey     760
# India      790
# dtype: int64

# %%
sales_total / 10
# Out:
# Japan     17.0
# China     87.0
# Turkey    38.0
# India     39.5
# dtype: float64

# %%
sales_q2 - sales_q1
# Out:
# Japan     10
# China    -30
# Turkey    80
# India     -5
# dtype: int64

# %%
q1 = {'Japan': 80, 'China' : 450 , 'India': 150 , 'USA' : 200 }
q2 = {'Brazil': 90, 'China' : 420 , 'India': 230 , 'USA' : 195 }

# %%
sales_q1 = pd.Series(q1)
sales_q2 = pd.Series(q2)

# %%
sales_q1
# Out:
# Japan     80
# China    450
# India    150
# USA      200
# dtype: int64

# %%
sales_q2
# Out:
# Brazil     90
# China     420
# India     230
# USA       195
# dtype: int64

# %%
sales_q1 + sales_q2
# Out:
# Brazil      NaN
# China     870.0
# India     380.0
# Japan       NaN
# USA       395.0
# dtype: float64

# %%
sales_q1.add(sales_q2 , fill_value = 0)
# Out:
# Brazil     90.0
# China     870.0
# India     380.0
# Japan      80.0
# USA       395.0
# dtype: float64

# %%
sales_q1
# Out:
# Japan     80
# China    450
# India    150
# USA      200
# dtype: int64

# %%
sales_q1.dtype
# Out:
# dtype('int64')

# %% [markdown]
# #DataFrame Basics

# %%
import numpy as np
import pandas as pd

# %%
my_data = np.random.randint(0,101 , size= (5,4))
my_data
# Out:
# array([[ 96,  85, 100,  36],
#        [  6,   2,  95,  19],
#        [  0,  35,  76,  91],
#        [ 20,   4,  81,  61],
#        [ 10,  80,   9,   0]])

# %%
pd.DataFrame(my_data)
# Out:
#     0   1    2   3
# 0  96  85  100  36
# 1   6   2   95  19
# 2   0  35   76  91
# 3  20   4   81  61
# 4  10  80    9   0

# %%
my_idx = ['TR' , 'BR' , 'USA' , 'RU']
my_cols = ['Jan' , 'Feb' , 'Mar']
my_data = np.random.randint(0,101, size= (4,3))

# %%
df = pd.DataFrame(data = my_data , index = my_idx , columns = my_cols)
df
# Out:
#      Jan  Feb  Mar
# TR    62   15   57
# BR    84   28   25
# USA   59   10   77
# RU    75   14   88

# %%
df.index = ['ali' , 'mehmet' , 'burak' , 'aslı']

# %%
df
# Out:
#         Jan  Feb  Mar
# ali      62   15   57
# mehmet   84   28   25
# burak    59   10   77
# aslı     75   14   88

# %%
df.columns = ['1-Not' , '2-Not' , '3-Not']

# %%
df
# Out:
#         1-Not  2-Not  3-Not
# ali        62     15     57
# mehmet     84     28     25
# burak      59     10     77
# aslı       75     14     88

# %%
df.info() # .info() metoduyla DF'in içindeki bütün columnların temel bilgilerini görebiliriz.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, ali to aslı
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1-Not   4 non-null      int64
#  1   2-Not   4 non-null      int64
#  2   3-Not   4 non-null      int64
# dtypes: int64(3)
# memory usage: 300.0+ bytes

# %% [markdown]
# #Hazır Bir Data Çağırmak

# %%
#https://www.kaggle.com/datasets/yasserh/housing-prices-dataset

# %%
df = pd.read_csv("/content/Housing.csv")
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.head(3)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished

# %%
df.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %%
df.tail(2)
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished

# %%
df.sample(5)
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 222  4760000  9166         2          1        1      yes        no      yes
# 435  3290000  4040         2          1        1      yes        no       no
# 278  4277000  3400         3          1        2      yes        no      yes
# 231  4690000  4320         3          1        1      yes        no       no
# 494  2730000  6800         2          1        1      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 222              no             yes        2       no   semi-furnished
# 435              no              no        0       no      unfurnished
# 278              no              no        2      yes   semi-furnished
# 231              no              no        0      yes   semi-furnished
# 494              no              no        0       no      unfurnished

# %%
df.shape
# Out:
# (545, 13)

# %%
df.shape[1]
# Out:
# 13

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
for i in df.columns:
  print("***************")
  print(i)
# Out:
# ***************
# price
# ***************
# area
# ***************
# bedrooms
# ***************
# bathrooms
# ***************
# stories
# ***************
# mainroad
# ***************
# guestroom
# ***************
# basement
# ***************
# hotwaterheating
# ***************
# airconditioning
# ***************
# parking
# ***************
# prefarea
# ***************
# furnishingstatus

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.describe().T
# Out:
#            count          mean           std        min        25%        50%  \
# price      545.0  4.766729e+06  1.870440e+06  1750000.0  3430000.0  4340000.0
# area       545.0  5.150541e+03  2.170141e+03     1650.0     3600.0     4600.0
# bedrooms   545.0  2.965138e+00  7.380639e-01        1.0        2.0        3.0
# bathrooms  545.0  1.286239e+00  5.024696e-01        1.0        1.0        1.0
# stories    545.0  1.805505e+00  8.674925e-01        1.0        1.0        2.0
# parking    545.0  6.935780e-01  8.615858e-01        0.0        0.0        0.0
#
#                  75%         max
# price      5740000.0  13300000.0
# area          6360.0     16200.0
# bedrooms         3.0         6.0
# bathrooms        2.0         4.0
# stories          2.0         4.0
# parking          1.0         3.0

# %% [markdown]
# #Column(Sütun) İşlemleri

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df["price"] # df.price
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
df[["price", "area"]]
# Out:
#         price  area
# 0    13300000  7420
# 1    12250000  8960
# 2    12250000  9960
# 3    12215000  7500
# 4    11410000  7420
# ..        ...   ...
# 540   1820000  3000
# 541   1767150  2400
# 542   1750000  3620
# 543   1750000  2910
# 544   1750000  3850
#
# [545 rows x 2 columns]

# %%
df.head(1)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished

# %%
# yeni bir feature oluşturalım.
# Mesela bir evdeki oda sayısı olsun.
# Bunun için bedrooms, bathrooms
# guestroom, basement bunlarda dahil edilebilir ama şu anlık etmeyeceğiz.

# %%
df["bedrooms"] + df["bathrooms"]
# Out:
# 0      6
# 1      8
# 2      5
# 3      6
# 4      5
#       ..
# 540    3
# 541    4
# 542    3
# 543    4
# 544    4
# Length: 545, dtype: int64

# %%
df["Total Rooms"] = df["bedrooms"] + df["bathrooms"]

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus  \
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
#
#    Total Rooms
# 0            6
# 1            8
# 2            5
# 3            6
# ...

# %%
# Örnek olarak hotwaterheating gereksiz diye düşünüp bunu drop edebiliriz.
df.drop("hotwaterheating", axis=1, inplace=True)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   airconditioning  parking prefarea furnishingstatus  Total Rooms
# 0             yes        2      yes        furnished            6
# 1             yes        3       no        furnished            8
# 2              no        2      yes   semi-furnished            5
# 3             yes        3      yes        furnished            6
# 4             yes        2       no        furnished            5

# %%
# Soru : df'in içerisinde stories column'unu ve mainroad columnu'nu düşürün ama kalıcı hale getirmeyin.
df.drop(["stories", "mainroad"], axis=1, inplace=False)
# Out:
#         price  area  bedrooms  bathrooms guestroom basement airconditioning  \
# 0    13300000  7420         4          2        no       no             yes
# 1    12250000  8960         4          4        no       no             yes
# 2    12250000  9960         3          2        no      yes              no
# 3    12215000  7500         4          2        no      yes             yes
# 4    11410000  7420         4          1       yes      yes             yes
# ..        ...   ...       ...        ...       ...      ...             ...
# 540   1820000  3000         2          1        no      yes              no
# 541   1767150  2400         3          1        no       no              no
# 542   1750000  3620         2          1        no       no              no
# 543   1750000  2910         3          1        no       no              no
# 544   1750000  3850         3          1        no       no              no
#
#      parking prefarea furnishingstatus  Total Rooms
# ...

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   airconditioning  parking prefarea furnishingstatus  Total Rooms
# 0             yes        2      yes        furnished            6
# 1             yes        3       no        furnished            8
# 2              no        2      yes   semi-furnished            5
# 3             yes        3      yes        furnished            6
# 4             yes        2       no        furnished            5

# %% [markdown]
# # Row(Satır) İşlemleri

# %%
# Satır çekme işlemi .loc ve .iloc metodları ile yapılır.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=545, step=1)

# %%
df.head(3)
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
#
#   airconditioning  parking prefarea furnishingstatus  Total Rooms
# 0             yes        2      yes        furnished            6
# 1             yes        3       no        furnished            8
# 2              no        2      yes   semi-furnished            5

# %%
df.set_index('price' , drop = True , inplace = True)

# %%
df.head(3)
# Out:
#           area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# price
# 13300000  7420         4          2        3      yes        no       no
# 12250000  8960         4          4        4      yes        no       no
# 12250000  9960         3          2        2      yes        no      yes
#
#          airconditioning  parking prefarea furnishingstatus  Total Rooms
# price
# 13300000             yes        2      yes        furnished            6
# 12250000             yes        3       no        furnished            8
# 12250000              no        2      yes   semi-furnished            5

# %%
df.iloc[1]
# Out:
# area                     8960
# bedrooms                    4
# bathrooms                   4
# stories                     4
# mainroad                  yes
# guestroom                  no
# basement                   no
# airconditioning           yes
# parking                     3
# prefarea                   no
# furnishingstatus    furnished
# Total Rooms                 8
# Name: 12250000, dtype: object

# %%
df.loc[12250000]
# Out:
#           area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# price
# 12250000  8960         4          4        4      yes        no       no
# 12250000  9960         3          2        2      yes        no      yes
#
#          airconditioning  parking prefarea furnishingstatus  Total Rooms
# price
# 12250000             yes        3       no        furnished            8
# 12250000              no        2      yes   semi-furnished            5

# %%
df.iloc[2:6]
# Out:
#           area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# price
# 12250000  9960         3          2        2      yes        no      yes
# 12215000  7500         4          2        2      yes        no      yes
# 11410000  7420         4          1        2      yes       yes      yes
# 10850000  7500         3          3        1      yes        no      yes
#
#          airconditioning  parking prefarea furnishingstatus  Total Rooms
# price
# 12250000              no        2      yes   semi-furnished            5
# 12215000             yes        3      yes        furnished            6
# 11410000             yes        2       no        furnished            5
# 10850000             yes        2      yes   semi-furnished            6

# %%
df.head()
# Out:
#           area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# price
# 13300000  7420         4          2        3      yes        no       no
# 12250000  8960         4          4        4      yes        no       no
# 12250000  9960         3          2        2      yes        no      yes
# 12215000  7500         4          2        2      yes        no      yes
# 11410000  7420         4          1        2      yes       yes      yes
#
#          airconditioning  parking prefarea furnishingstatus  Total Rooms
# price
# 13300000             yes        2      yes        furnished            6
# 12250000             yes        3       no        furnished            8
# 12250000              no        2      yes   semi-furnished            5
# 12215000             yes        3      yes        furnished            6
# 11410000             yes        2       no        furnished            5

# %%
df.loc[12250000 : 11410000] # Stop noktası dahil.
# Out:
#           area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# price
# 12250000  8960         4          4        4      yes        no       no
# 12250000  9960         3          2        2      yes        no      yes
# 12215000  7500         4          2        2      yes        no      yes
# 11410000  7420         4          1        2      yes       yes      yes
#
#          airconditioning  parking prefarea furnishingstatus  Total Rooms
# price
# 12250000             yes        3       no        furnished            8
# 12250000              no        2      yes   semi-furnished            5
# 12215000             yes        3      yes        furnished            6
# 11410000             yes        2       no        furnished            5

# %% [markdown]
# # DataFrame'de Sorgu İşlemleri

# %%
df = pd.read_csv("Housing.csv")

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df["bedrooms"] > 3
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 540    False
# 541    False
# 542    False
# 543    False
# 544    False
# Name: bedrooms, Length: 545, dtype: bool

# %%
df[df["bedrooms"] > 3]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# 6    10150000  8580         4          3        4      yes        no       no
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 487   2870000  5400         4          1        2      yes        no       no
# 488   2852500  5200         4          1        3      yes        no       no
# 523   2380000  2787         4          2        2      yes        no       no
# 534   2100000  3000         4          1        2      yes        no       no
# 536   1960000  3420         5          1        2       no        no       no
#
# ...

# %%
# Soru: Siz de stories 3 den küçük olan evleri getirin.
df["stories"] < 3
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 540     True
# 541     True
# 542     True
# 543     True
# 544     True
# Name: stories, Length: 545, dtype: bool

# %%
df[df["stories"] < 3]
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 2    12250000   9960         3          2        2      yes        no
# 3    12215000   7500         4          2        2      yes        no
# 4    11410000   7420         4          1        2      yes       yes
# 5    10850000   7500         3          3        1      yes        no
# 7    10150000  16200         5          3        2      yes        no
# ..        ...    ...       ...        ...      ...      ...       ...
# 540   1820000   3000         2          1        1      yes        no
# 541   1767150   2400         3          1        1       no        no
# 542   1750000   3620         2          1        1      yes        no
# 543   1750000   2910         3          1        1       no        no
# 544   1750000   3850         3          1        2      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
# Evimde airconditioning olsun istiyorum bu evleri bana göstersin
df["airconditioning"] == "yes"
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 540    False
# 541    False
# 542    False
# 543    False
# 544    False
# Name: airconditioning, Length: 545, dtype: bool

# %%
df[df["airconditioning"] == "yes"]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# 5    10850000  7500         3          3        1      yes        no      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 457   3115000  3000         3          1        1       no        no       no
# 461   3080000  4960         2          1        1      yes        no      yes
# 504   2653000  3185         2          1        1      yes        no       no
# 505   2653000  4000         3          1        2      yes        no       no
# 531   2233000  5300         3          1        1       no        no       no
#
# ...

# %%
(df["airconditioning"] == "yes") & (df["stories"] < 3)
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4       True
#        ...
# 540    False
# 541    False
# 542    False
# 543    False
# 544    False
# Length: 545, dtype: bool

# %%
df[(df["airconditioning"] == "yes") & (df["stories"] < 3)]
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 3    12215000   7500         4          2        2      yes        no
# 4    11410000   7420         4          1        2      yes       yes
# 5    10850000   7500         3          3        1      yes        no
# 8     9870000   8100         4          1        2      yes       yes
# 10    9800000  13200         3          1        2      yes        no
# ..        ...    ...       ...        ...      ...      ...       ...
# 457   3115000   3000         3          1        1       no        no
# 461   3080000   4960         2          1        1      yes        no
# 504   2653000   3185         2          1        1      yes        no
# 505   2653000   4000         3          1        2      yes        no
# 531   2233000   5300         3          1        1       no        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
df[df['furnishingstatus'].isin(['furnished' , 'semi-furnished'])]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 522   2380000  2475         3          1        2      yes        no       no
# 523   2380000  2787         4          2        2      yes        no       no
# 527   2275000  1836         2          1        1       no        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 543   1750000  2910         3          1        1       no        no       no
#
# ...

# %%
df[df['furnishingstatus'] != 'unfurnished']
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 522   2380000  2475         3          1        2      yes        no       no
# 523   2380000  2787         4          2        2      yes        no       no
# 527   2275000  1836         2          1        1       no        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 543   1750000  2910         3          1        1       no        no       no
#
# ...

# %% [markdown]
# #Pandasda sık kullanılan Fonksiyon ve Metodlar
#
#
# * apply() method
# * apply() with a function
# * apply() with a lambda expression
# * apply() on multiple columns
# * describe()
# * sort_values()
# * select_dtypes()
# * corr()
# * value_counts()
# * replace()
# * unique and nunique()
# * map()
# * duplicated and drop_duplicates()
# * between()
# * sample()
# * nlargest()

# %% [markdown]
# ## .apply() Methodu

# %%
# .apply() methodu bir series ya da datadrame'in sütunlarındaki değelerin hepsine bir anda bir fonksiyon'u uygulamaya yarar.
# Arka planında for döngüsü çalışır dolayısıyla çok hızlı değildir. Performans açısından vektörize edilmiş işlemleri uygulamak daha faydalıdır.
# Özellikle vektörize edilmiş işlemler oldukça hızlı çalışır ve for döngüsü kullanımını minimize eder.
# Ancak diğer taraftan .apply() methodunu kullanmak oldukça okunaklıdır. Başlangıçta kolaydır ve her duruma uygulanabilir. Ancak vektörize işlemler bazı durumlarda yapılamayabilir.

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
# Amaç: price sütununun son 3 sıfırını silelim.

# %% [markdown]
# ### 1.Yol

# %%
def delZero(x):
  return int(str(x)[:-3])

# %%
delZero(13300000)
# Out:
# 13300

# %%
# df["price"] = df["price"].apply(delZero)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# ### 2.Yol

# %%
# df["price"] = df["price"].apply(lambda x: int(str(x)[:-3]))

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %% [markdown]
# ### 3.Yol (Vectorized)

# %%
# df["price"] // 10**3

# %%
# df["price"].astype(str).str[:-3]

# %%
# Amaç: price sütununda bulunan değerlerin sonuna dolar işareti koyma

# %% [markdown]
# ### 1.Yol

# %%
def putDolar(x):
  return str(x) + "$"

# %%
putDolar(13300000)
# Out:
# '13300000$'

# %%
# df["price"] = df["price"].apply(putDolar)
# df.head()

# %% [markdown]
# ### 2.Yol

# %%
df["price"].apply(lambda x: str(x) + "$")
# Out:
# 0      13300000$
# 1      12250000$
# 2      12250000$
# 3      12215000$
# 4      11410000$
#          ...
# 540     1820000$
# 541     1767150$
# 542     1750000$
# 543     1750000$
# 544     1750000$
# Name: price, Length: 545, dtype: object

# %% [markdown]
# ### 3.Yol (Vectorized)

# %%
df["price"].astype(str) + "$"
# Out:
# 0      13300000$
# 1      12250000$
# 2      12250000$
# 3      12215000$
# 4      11410000$
#          ...
# 540     1820000$
# 541     1767150$
# 542     1750000$
# 543     1750000$
# 544     1750000$
# Name: price, Length: 545, dtype: object

# %%
# Apply methodunu aynı anda birden fazla sütın için yapabiliriz.

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df[["price", "area"]].applymap(putDolar)
# Out:
# <ipython-input-113-6dc84f812234>:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df[["price", "area"]].applymap(putDolar)
#          price   area
# 0    13300000$  7420$
# 1    12250000$  8960$
# 2    12250000$  9960$
# 3    12215000$  7500$
# 4    11410000$  7420$
# ..         ...    ...
# 540   1820000$  3000$
# 541   1767150$  2400$
# 542   1750000$  3620$
# 543   1750000$  2910$
# 544   1750000$  3850$
#
# [545 rows x 2 columns]

# %%
df[["price", "area"]].astype(str) + "$"
# Out:
#          price   area
# 0    13300000$  7420$
# 1    12250000$  8960$
# 2    12250000$  9960$
# 3    12215000$  7500$
# 4    11410000$  7420$
# ..         ...    ...
# 540   1820000$  3000$
# 541   1767150$  2400$
# 542   1750000$  3620$
# 543   1750000$  2910$
# 544   1750000$  3850$
#
# [545 rows x 2 columns]

# %% [markdown]
# ## .sort_values()

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.sort_values(by = "area")
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 449   3150000   1650         3          1        2       no        no
# 537   1890000   1700         3          1        2      yes        no
# 527   2275000   1836         2          1        1       no        no
# 271   4340000   1905         5          1        2       no        no
# 413   3430000   1950         3          2        2      yes        no
# ..        ...    ...       ...        ...      ...      ...       ...
# 403   3500000  12944         3          1        1      yes        no
# 10    9800000  13200         3          1        2      yes        no
# 66    6930000  13200         2          1        1      yes        no
# 125   5943000  15600         3          1        1      yes        no
# 7    10150000  16200         5          3        2      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
df.sort_values(by = "area", ascending = False, inplace=True)

# %%
df.head()
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 7    10150000  16200         5          3        2      yes        no
# 125   5943000  15600         3          1        1      yes        no
# 66    6930000  13200         2          1        1      yes        no
# 10    9800000  13200         3          1        2      yes        no
# 403   3500000  12944         3          1        1      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# 7         no              no              no        0       no
# 125       no              no             yes        2       no
# 66       yes             yes              no        1       no
# 10       yes              no             yes        2      yes
# 403       no              no              no        0       no
#
#     furnishingstatus
# 7        unfurnished
# 125   semi-furnished
# 66         furnished
# 10         furnished
# 403      unfurnished

# %%
df.reset_index()
# Out:
#      index     price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0        7  10150000  16200         5          3        2      yes        no
# 1      125   5943000  15600         3          1        1      yes        no
# 2       66   6930000  13200         2          1        1      yes        no
# 3       10   9800000  13200         3          1        2      yes        no
# 4      403   3500000  12944         3          1        1      yes        no
# ..     ...       ...    ...       ...        ...      ...      ...       ...
# 540    413   3430000   1950         3          2        2      yes        no
# 541    271   4340000   1905         5          1        2       no        no
# 542    527   2275000   1836         2          1        1       no        no
# 543    537   1890000   1700         3          1        2      yes        no
# 544    449   3150000   1650         3          1        2       no        no
#
# ...

# %%
df.reset_index(drop=True)
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 0    10150000  16200         5          3        2      yes        no
# 1     5943000  15600         3          1        1      yes        no
# 2     6930000  13200         2          1        1      yes        no
# 3     9800000  13200         3          1        2      yes        no
# 4     3500000  12944         3          1        1      yes        no
# ..        ...    ...       ...        ...      ...      ...       ...
# 540   3430000   1950         3          2        2      yes        no
# 541   4340000   1905         5          1        2       no        no
# 542   2275000   1836         2          1        1       no        no
# 543   1890000   1700         3          1        2      yes        no
# 544   3150000   1650         3          1        2       no        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
df.head()
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 7    10150000  16200         5          3        2      yes        no
# 125   5943000  15600         3          1        1      yes        no
# 66    6930000  13200         2          1        1      yes        no
# 10    9800000  13200         3          1        2      yes        no
# 403   3500000  12944         3          1        1      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# 7         no              no              no        0       no
# 125       no              no             yes        2       no
# 66       yes             yes              no        1       no
# 10       yes              no             yes        2      yes
# 403       no              no              no        0       no
#
#     furnishingstatus
# 7        unfurnished
# 125   semi-furnished
# 66         furnished
# 10         furnished
# 403      unfurnished

# %%
df.sort_values(by = ["area", "price"], ascending=False)
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 7    10150000  16200         5          3        2      yes        no
# 125   5943000  15600         3          1        1      yes        no
# 10    9800000  13200         3          1        2      yes        no
# 66    6930000  13200         2          1        1      yes        no
# 403   3500000  12944         3          1        1      yes        no
# ..        ...    ...       ...        ...      ...      ...       ...
# 530   2240000   1950         3          1        1       no        no
# 271   4340000   1905         5          1        2       no        no
# 527   2275000   1836         2          1        1       no        no
# 537   1890000   1700         3          1        2      yes        no
# 449   3150000   1650         3          1        2       no        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
df["bedrooms"].max()
# Out:
# 6

# %%
df["bedrooms"].argmax()
# Out:
# 306

# %%
df.iloc[306]
# Out:
# price                 6083000
# area                     4300
# bedrooms                    6
# bathrooms                   2
# stories                     2
# mainroad                  yes
# guestroom                  no
# basement                   no
# hotwaterheating            no
# airconditioning            no
# parking                     0
# prefarea                   no
# furnishingstatus    furnished
# Name: 112, dtype: object

# %% [markdown]
# ## .select_dtypes()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 545 entries, 7 to 449
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 59.6+ KB

# %%
df.select_dtypes(include = ["number"])
# Out:
#         price   area  bedrooms  bathrooms  stories  parking
# 7    10150000  16200         5          3        2        0
# 125   5943000  15600         3          1        1        2
# 66    6930000  13200         2          1        1        1
# 10    9800000  13200         3          1        2        2
# 403   3500000  12944         3          1        1        0
# ..        ...    ...       ...        ...      ...      ...
# 413   3430000   1950         3          2        2        0
# 271   4340000   1905         5          1        2        0
# 527   2275000   1836         2          1        1        0
# 537   1890000   1700         3          1        2        0
# 449   3150000   1650         3          1        2        0
#
# [545 rows x 6 columns]

# %% [markdown]
# ## .corr()

# %%
df.corr() # Makine öğrenmesi modelleri kurarken hayati öneme sahip.
          # Numeric columnlar arasındaki doğrusal ilişkileri gösteriyor.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-128-23a6974c24d2> in <cell line: 1>()
# ----> 1 df.corr() # Makine öğrenmesi modelleri kurarken hayati öneme sahip.
#       2           # Numeric columnlar arasındaki doğrusal ilişkileri gösteriyor.
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   11047         cols = data.columns
#   11048         idx = cols.copy()
# > 11049         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11050
#   11051         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1991         if dtype is not None:
#    1992             dtype = np.dtype(dtype)
# -> 1993         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
# ...

# %%
numeric_df = df.select_dtypes("number")
numeric_df
# Out:
#         price   area  bedrooms  bathrooms  stories  parking
# 7    10150000  16200         5          3        2        0
# 125   5943000  15600         3          1        1        2
# 66    6930000  13200         2          1        1        1
# 10    9800000  13200         3          1        2        2
# 403   3500000  12944         3          1        1        0
# ..        ...    ...       ...        ...      ...      ...
# 413   3430000   1950         3          2        2        0
# 271   4340000   1905         5          1        2        0
# 527   2275000   1836         2          1        1        0
# 537   1890000   1700         3          1        2        0
# 449   3150000   1650         3          1        2        0
#
# [545 rows x 6 columns]

# %%
numeric_df.corr()
# Out:
#               price      area  bedrooms  bathrooms   stories   parking
# price      1.000000  0.535997  0.366494   0.517545  0.420712  0.384394
# area       0.535997  1.000000  0.151858   0.193820  0.083996  0.352980
# bedrooms   0.366494  0.151858  1.000000   0.373930  0.408564  0.139270
# bathrooms  0.517545  0.193820  0.373930   1.000000  0.326165  0.177496
# stories    0.420712  0.083996  0.408564   0.326165  1.000000  0.045547
# parking    0.384394  0.352980  0.139270   0.177496  0.045547  1.000000

# %% [markdown]
# ## value_counts()

# %%
df.head()
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 7    10150000  16200         5          3        2      yes        no
# 125   5943000  15600         3          1        1      yes        no
# 66    6930000  13200         2          1        1      yes        no
# 10    9800000  13200         3          1        2      yes        no
# 403   3500000  12944         3          1        1      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# 7         no              no              no        0       no
# 125       no              no             yes        2       no
# 66       yes             yes              no        1       no
# 10       yes              no             yes        2      yes
# 403       no              no              no        0       no
#
#     furnishingstatus
# 7        unfurnished
# 125   semi-furnished
# 66         furnished
# 10         furnished
# 403      unfurnished

# %%
df.shape
# Out:
# (545, 13)

# %%
df["bedrooms"].value_counts()
# Out:
# bedrooms
# 3    300
# 2    136
# 4     95
# 5     10
# 6      2
# 1      2
# Name: count, dtype: int64

# %%
df.bedrooms.value_counts()
# Out:
# bedrooms
# 3    300
# 2    136
# 4     95
# 5     10
# 6      2
# 1      2
# Name: count, dtype: int64

# %%
df["bedrooms"].unique()
# Out:
# array([5, 3, 2, 4, 6, 1])

# %%
df["bedrooms"].value_counts().keys()
# Out:
# Index([3, 2, 4, 5, 6, 1], dtype='int64', name='bedrooms')

# %%
df["bedrooms"].value_counts().values
# Out:
# array([300, 136,  95,  10,   2,   2])

# %% [markdown]
# ## replace()

# %%
df.head()
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 7    10150000  16200         5          3        2      yes        no
# 125   5943000  15600         3          1        1      yes        no
# 66    6930000  13200         2          1        1      yes        no
# 10    9800000  13200         3          1        2      yes        no
# 403   3500000  12944         3          1        1      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# 7         no              no              no        0       no
# 125       no              no             yes        2       no
# 66       yes             yes              no        1       no
# 10       yes              no             yes        2      yes
# 403       no              no              no        0       no
#
#     furnishingstatus
# 7        unfurnished
# 125   semi-furnished
# 66         furnished
# 10         furnished
# 403      unfurnished

# %%
df["mainroad"].value_counts()
# Out:
# mainroad
# yes    468
# no      77
# Name: count, dtype: int64

# %%
# Amaç: "yes" 1 olsun "no" 0 olsun

# %% [markdown]
# ### 1.Yol (apply())

# %%
def makeNumeric(x):
  if str(x) == "yes":
    x = 1
  else:
    x = 0
  return x

# %%
df["mainroad"].apply(makeNumeric)
# Out:
# 7      1
# 125    1
# 66     1
# 10     1
# 403    1
#       ..
# 413    1
# 271    0
# 527    0
# 537    1
# 449    0
# Name: mainroad, Length: 545, dtype: int64

# %% [markdown]
# ### 2.Yol (.replace() Metodu ile)

# %%
df.head()
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 7    10150000  16200         5          3        2      yes        no
# 125   5943000  15600         3          1        1      yes        no
# 66    6930000  13200         2          1        1      yes        no
# 10    9800000  13200         3          1        2      yes        no
# 403   3500000  12944         3          1        1      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# 7         no              no              no        0       no
# 125       no              no             yes        2       no
# 66       yes             yes              no        1       no
# 10       yes              no             yes        2      yes
# 403       no              no              no        0       no
#
#     furnishingstatus
# 7        unfurnished
# 125   semi-furnished
# 66         furnished
# 10         furnished
# 403      unfurnished

# %%
df["mainroad"].replace("yes", 1)
# Out:
# 7       1
# 125     1
# 66      1
# 10      1
# 403     1
#        ..
# 413     1
# 271    no
# 527    no
# 537     1
# 449    no
# Name: mainroad, Length: 545, dtype: object

# %%
df["mainroad"].replace("no", 0)
# Out:
# 7      yes
# 125    yes
# 66     yes
# 10     yes
# 403    yes
#       ...
# 413    yes
# 271      0
# 527      0
# 537    yes
# 449      0
# Name: mainroad, Length: 545, dtype: object

# %%
df["mainroad"].replace(["yes", "no"], [1, 0])
# Out:
# <ipython-input-146-01f8f74f86b0>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["mainroad"].replace(["yes", "no"], [1, 0])
# 7      1
# 125    1
# 66     1
# 10     1
# 403    1
#       ..
# 413    1
# 271    0
# 527    0
# 537    1
# 449    0
# Name: mainroad, Length: 545, dtype: int64

# %% [markdown]
# ### 3.Yol map()

# %%
df.head()
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 7    10150000  16200         5          3        2      yes        no
# 125   5943000  15600         3          1        1      yes        no
# 66    6930000  13200         2          1        1      yes        no
# 10    9800000  13200         3          1        2      yes        no
# 403   3500000  12944         3          1        1      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# 7         no              no              no        0       no
# 125       no              no             yes        2       no
# 66       yes             yes              no        1       no
# 10       yes              no             yes        2      yes
# 403       no              no              no        0       no
#
#     furnishingstatus
# 7        unfurnished
# 125   semi-furnished
# 66         furnished
# 10         furnished
# 403      unfurnished

# %%
df["mainroad"].map({"yes":1,
                    "no":0})
# Out:
# 7      1
# 125    1
# 66     1
# 10     1
# 403    1
#       ..
# 413    1
# 271    0
# 527    0
# 537    1
# 449    0
# Name: mainroad, Length: 545, dtype: int64

# %% [markdown]
# ## duplicated and drop_duplicates()

# %%
df.head()
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 7    10150000  16200         5          3        2      yes        no
# 125   5943000  15600         3          1        1      yes        no
# 66    6930000  13200         2          1        1      yes        no
# 10    9800000  13200         3          1        2      yes        no
# 403   3500000  12944         3          1        1      yes        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# 7         no              no              no        0       no
# 125       no              no             yes        2       no
# 66       yes             yes              no        1       no
# 10       yes              no             yes        2      yes
# 403       no              no              no        0       no
#
#     furnishingstatus
# 7        unfurnished
# 125   semi-furnished
# 66         furnished
# 10         furnished
# 403      unfurnished

# %%
df.duplicated().sum()
# Out:
# 0

# %%
dicti = {
    "a": [1,1,3,4],
    "b": [5,5,7,8],
    "c": [1,1,3,4]
}

# %%
df_dup = pd.DataFrame(dicti)

# %%
df_dup
# Out:
#    a  b  c
# 0  1  5  1
# 1  1  5  1
# 2  3  7  3
# 3  4  8  4

# %%
df_dup.duplicated()
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# dtype: bool

# %%
df_dup.drop_duplicates()
# Out:
#    a  b  c
# 0  1  5  1
# 2  3  7  3
# 3  4  8  4

# %% [markdown]
# ## Sorgu İşlemleri

# %%
df
# Out:
#         price   area  bedrooms  bathrooms  stories mainroad guestroom  \
# 7    10150000  16200         5          3        2      yes        no
# 125   5943000  15600         3          1        1      yes        no
# 66    6930000  13200         2          1        1      yes        no
# 10    9800000  13200         3          1        2      yes        no
# 403   3500000  12944         3          1        1      yes        no
# ..        ...    ...       ...        ...      ...      ...       ...
# 413   3430000   1950         3          2        2      yes        no
# 271   4340000   1905         5          1        2       no        no
# 527   2275000   1836         2          1        1       no        no
# 537   1890000   1700         3          1        2      yes        no
# 449   3150000   1650         3          1        2       no        no
#
#     basement hotwaterheating airconditioning  parking prefarea  \
# ...

# %%
df[df["price"] < 5000000]
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 403  3500000  12944         3          1        1      yes        no       no
# 211  4900000  12900         3          1        1      yes        no       no
# 277  4305000  10360         2          1        1      yes        no       no
# 224  4760000  10240         2          1        1      yes        no       no
# 252  4515000   9860         3          1        1      yes        no       no
# ..       ...    ...       ...        ...      ...      ...       ...      ...
# 413  3430000   1950         3          2        2      yes        no      yes
# 271  4340000   1905         5          1        2       no        no      yes
# 527  2275000   1836         2          1        1       no        no      yes
# 537  1890000   1700         3          1        2      yes        no       no
# 449  3150000   1650         3          1        2       no        no      yes
#
# ...

# %%
# fiyatı 3 ve 5 milyon arası olan evleri getir

# %%
df["price"] < 5000000 & df["price"] > 3000000
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-159-b88d82c0c32e> in <cell line: 1>()
# ----> 1 df["price"] < 5000000 & df["price"] > 3000000
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df[df["price"].between(3000000, 5000000)] # Default ayarlarda inclusive = 'both' dur. Yani iki taraf da dahildir.
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 403  3500000  12944         3          1        1      yes        no       no
# 211  4900000  12900         3          1        1      yes        no       no
# 277  4305000  10360         2          1        1      yes        no       no
# 224  4760000  10240         2          1        1      yes        no       no
# 252  4515000   9860         3          1        1      yes        no       no
# ..       ...    ...       ...        ...      ...      ...       ...      ...
# 390  3500000   2135         3          2        2       no        no       no
# 345  3850000   2015         3          1        2      yes        no      yes
# 413  3430000   1950         3          2        2      yes        no      yes
# 271  4340000   1905         5          1        2       no        no      yes
# 449  3150000   1650         3          1        2       no        no      yes
#
# ...

# %%
df[df["price"].between(3000000, 5000000, inclusive = "right")]
# Out:
#        price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 403  3500000  12944         3          1        1      yes        no       no
# 211  4900000  12900         3          1        1      yes        no       no
# 277  4305000  10360         2          1        1      yes        no       no
# 224  4760000  10240         2          1        1      yes        no       no
# 252  4515000   9860         3          1        1      yes        no       no
# ..       ...    ...       ...        ...      ...      ...       ...      ...
# 390  3500000   2135         3          2        2       no        no       no
# 345  3850000   2015         3          1        2      yes        no      yes
# 413  3430000   1950         3          2        2      yes        no      yes
# 271  4340000   1905         5          1        2       no        no      yes
# 449  3150000   1650         3          1        2       no        no      yes
#
# ...

# %%
df.nlargest(8, "price")
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 1  12250000   8960         4          4        4      yes        no       no
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 7  10150000  16200         5          3        2      yes        no       no
# 6  10150000   8580         4          3        4      yes        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 2              no              no        2      yes   semi-furnished
# 1              no             yes        3       no        furnished
# ...

# %%
df.sort_values("price", ascending=False).head(8)
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 1  12250000   8960         4          4        4      yes        no       no
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 2              no              no        2      yes   semi-furnished
# 1              no             yes        3       no        furnished
# ...

# %%
df.nsmallest(8, "price")
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 544  1750000  3850         3          1        2      yes        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 541  1767150  2400         3          1        1       no        no       no
# 540  1820000  3000         2          1        1      yes        no      yes
# 539  1855000  2990         2          1        1       no        no       no
# 538  1890000  3649         2          1        1      yes        no       no
# 537  1890000  1700         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 544              no              no        0       no      unfurnished
# 542              no              no        0       no      unfurnished
# ...

# %% [markdown]
# # Missing Values(Eksik Veriler)

# %%
# Missing value kavramı 'Eksik veri' anlamına gelir ve datamız içindeki değeri bilinmeyen verileri ifade eder.
# Missing valuelar farklı formatlarda olabilir.

# %%
np.nan # En sık karşılaşacağımız eksik veri tipi budur.
# Out:
# nan

# %%
pd.NA

# %%
pd.NaT
# Out:
# NaT

# %%
5 == 5
# Out:
# True

# %%
np.nan == np.nan # Bir verinin nan olup olmadığını bu şekilde kontrol edemeyiz.
# Out:
# False

# %%
dfEmpty = pd.read_csv("/content/HousingWithMissingValues.csv")
dfEmpty.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420       4.0          2      3.0      yes        no       no
# 1  12250000  8960       4.0          4      4.0      yes        no       no
# 2  12250000  9960       3.0          2      2.0      yes        no      yes
# 3  12215000  7500       4.0          2      2.0      yes        no      yes
# 4  11410000  7420       4.0          1      2.0      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes      2.0      yes        furnished
# 1              no             yes      3.0       no        furnished
# 2              no              no      NaN      yes   semi-furnished
# 3              no             yes      3.0      yes        furnished
# 4              no             yes      2.0       no        furnished

# %%
dfEmpty.isna()
# Out:
#      price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    False  False     False      False    False     False      False
# 1    False  False     False      False    False     False      False
# 2    False  False     False      False    False     False      False
# 3    False  False     False      False    False     False      False
# 4    False  False     False      False    False     False      False
# ..     ...    ...       ...        ...      ...       ...        ...
# 540  False  False     False      False    False     False      False
# 541  False  False     False      False    False     False      False
# 542  False  False     False      False    False     False      False
# 543  False  False     False      False    False     False      False
# 544  False  False     False      False    False     False      False
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0       False            False            False    False     False
# ...

# %%
dfEmpty.isna().sum()
# Out:
# price               0
# area                0
# bedrooms            2
# bathrooms           0
# stories             4
# mainroad            0
# guestroom           4
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             2
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
# Amaç: bedrooms sütununda boş değerler olan satırları getirme

# %%
dfEmpty[dfEmpty["bedrooms"].isna()]
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 273  4340000  3500       NaN          1      NaN      yes        no       no
# 425  3360000  3185       NaN          1      NaN      yes        no      yes
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 273              no              no      2.0       no        furnished
# 425              no              no      2.0       no        furnished

# %%
dfEmpty.notna()
# Out:
#      price  area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0     True  True      True       True     True      True       True      True
# 1     True  True      True       True     True      True       True      True
# 2     True  True      True       True     True      True       True      True
# 3     True  True      True       True     True      True       True      True
# 4     True  True      True       True     True      True       True      True
# ..     ...   ...       ...        ...      ...       ...        ...       ...
# 540   True  True      True       True     True      True       True      True
# 541   True  True      True       True     True      True       True      True
# 542   True  True      True       True     True      True       True      True
# 543   True  True      True       True     True      True       True      True
# 544   True  True      True       True     True      True       True      True
#
# ...

# %%
# Amaç: stories sütununda not olmayan değerleri getir

# %%
dfEmpty[dfEmpty["stories"].notna()]
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420       4.0          2      3.0      yes        no       no
# 1    12250000  8960       4.0          4      4.0      yes        no       no
# 2    12250000  9960       3.0          2      2.0      yes        no      yes
# 3    12215000  7500       4.0          2      2.0      yes        no      yes
# 4    11410000  7420       4.0          1      2.0      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000       2.0          1      1.0      yes        no      yes
# 541   1767150  2400       3.0          1      1.0       no        no       no
# 542   1750000  3620       2.0          1      1.0      yes        no       no
# 543   1750000  2910       3.0          1      1.0       no        no       no
# 544   1750000  3850       3.0          1      2.0      yes        no       no
#
# ...

# %%
# Amaç: bedrooms sütunu nan olmayan ve stories sütunu nan olan satırları getir

# %%
dfEmpty[(dfEmpty["bedrooms"].notna()) & (dfEmpty["stories"].isna())]
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 282  4270000  2175       3.0          1      NaN       no       yes      yes
# 488  2852500  5200       4.0          1      NaN      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 282              no             yes      0.0       no      unfurnished
# 488              no              no      0.0       no      unfurnished

# %% [markdown]
# # Missing Valuelarla Yapılabilecek 3 şey vardır

# %%
# 1) Dokunmadan bırakabiliriz.
# 2) Drop edebiliriz(Satır veya sütun bazlı)
# 3) Mantıklı bir şekilde doldurabiliriz.

# %%
dfEmpty.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420       4.0          2      3.0      yes        no       no
# 1  12250000  8960       4.0          4      4.0      yes        no       no
# 2  12250000  9960       3.0          2      2.0      yes        no      yes
# 3  12215000  7500       4.0          2      2.0      yes        no      yes
# 4  11410000  7420       4.0          1      2.0      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes      2.0      yes        furnished
# 1              no             yes      3.0       no        furnished
# 2              no              no      NaN      yes   semi-furnished
# 3              no             yes      3.0      yes        furnished
# 4              no             yes      2.0       no        furnished

# %% [markdown]
# ## 1.Yol (Görmezden gel)

# %% [markdown]
# ## 2. Yol (Drop etmek)

# %%
dfEmpty.dropna()
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420       4.0          2      3.0      yes        no       no
# 1    12250000  8960       4.0          4      4.0      yes        no       no
# 3    12215000  7500       4.0          2      2.0      yes        no      yes
# 4    11410000  7420       4.0          1      2.0      yes       yes      yes
# 5    10850000  7500       3.0          3      1.0      yes        no      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000       2.0          1      1.0      yes        no      yes
# 541   1767150  2400       3.0          1      1.0       no        no       no
# 542   1750000  3620       2.0          1      1.0      yes        no       no
# 543   1750000  2910       3.0          1      1.0       no        no       no
# 544   1750000  3850       3.0          1      2.0      yes        no       no
#
# ...

# %%
dfEmpty.dropna(how = 'any') # Herhangi bir sütunu nan ise o satırı düşür.
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420       4.0          2      3.0      yes        no       no
# 1    12250000  8960       4.0          4      4.0      yes        no       no
# 3    12215000  7500       4.0          2      2.0      yes        no      yes
# 4    11410000  7420       4.0          1      2.0      yes       yes      yes
# 5    10850000  7500       3.0          3      1.0      yes        no      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000       2.0          1      1.0      yes        no      yes
# 541   1767150  2400       3.0          1      1.0       no        no       no
# 542   1750000  3620       2.0          1      1.0      yes        no       no
# 543   1750000  2910       3.0          1      1.0       no        no       no
# 544   1750000  3850       3.0          1      2.0      yes        no       no
#
# ...

# %%
dfEmpty.dropna(how = 'all') # Bütün sütunları nan ise o satırı düşür.
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420       4.0          2      3.0      yes        no       no
# 1    12250000  8960       4.0          4      4.0      yes        no       no
# 2    12250000  9960       3.0          2      2.0      yes        no      yes
# 3    12215000  7500       4.0          2      2.0      yes        no      yes
# 4    11410000  7420       4.0          1      2.0      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000       2.0          1      1.0      yes        no      yes
# 541   1767150  2400       3.0          1      1.0       no        no       no
# 542   1750000  3620       2.0          1      1.0      yes        no       no
# 543   1750000  2910       3.0          1      1.0       no        no       no
# 544   1750000  3850       3.0          1      2.0      yes        no       no
#
# ...

# %%
dfEmpty.dropna(thresh= 1) # 1 tane bile nan olmayan veri varsa o satırı tut.
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420       4.0          2      3.0      yes        no       no
# 1    12250000  8960       4.0          4      4.0      yes        no       no
# 2    12250000  9960       3.0          2      2.0      yes        no      yes
# 3    12215000  7500       4.0          2      2.0      yes        no      yes
# 4    11410000  7420       4.0          1      2.0      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000       2.0          1      1.0      yes        no      yes
# 541   1767150  2400       3.0          1      1.0       no        no       no
# 542   1750000  3620       2.0          1      1.0      yes        no       no
# 543   1750000  2910       3.0          1      1.0       no        no       no
# 544   1750000  3850       3.0          1      2.0      yes        no       no
#
# ...

# %%
dfEmpty.columns.shape
# Out:
# (13,)

# %%
dfEmpty.dropna(thresh= 12) # 1 tane bile nan olmayan veri varsa o satırı tut.
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420       4.0          2      3.0      yes        no       no
# 1    12250000  8960       4.0          4      4.0      yes        no       no
# 2    12250000  9960       3.0          2      2.0      yes        no      yes
# 3    12215000  7500       4.0          2      2.0      yes        no      yes
# 4    11410000  7420       4.0          1      2.0      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000       2.0          1      1.0      yes        no      yes
# 541   1767150  2400       3.0          1      1.0       no        no       no
# 542   1750000  3620       2.0          1      1.0      yes        no       no
# 543   1750000  2910       3.0          1      1.0       no        no       no
# 544   1750000  3850       3.0          1      2.0      yes        no       no
#
# ...

# %%
dfEmpty.dropna(axis = 1 , thresh = 542)
# Out:
#         price  area  bedrooms  bathrooms mainroad basement hotwaterheating  \
# 0    13300000  7420       4.0          2      yes       no              no
# 1    12250000  8960       4.0          4      yes       no              no
# 2    12250000  9960       3.0          2      yes      yes              no
# 3    12215000  7500       4.0          2      yes      yes              no
# 4    11410000  7420       4.0          1      yes      yes              no
# ..        ...   ...       ...        ...      ...      ...             ...
# 540   1820000  3000       2.0          1      yes      yes              no
# 541   1767150  2400       3.0          1       no       no              no
# 542   1750000  3620       2.0          1      yes       no              no
# 543   1750000  2910       3.0          1       no       no              no
# 544   1750000  3850       3.0          1      yes       no              no
#
#     airconditioning  parking prefarea furnishingstatus
# ...

# %% [markdown]
# ## 3.Yol : Fill the data(Datayı doldur.)

# %%
dfEmpty.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420       4.0          2      3.0      yes        no       no
# 1  12250000  8960       4.0          4      4.0      yes        no       no
# 2  12250000  9960       3.0          2      2.0      yes        no      yes
# 3  12215000  7500       4.0          2      2.0      yes        no      yes
# 4  11410000  7420       4.0          1      2.0      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes      2.0      yes        furnished
# 1              no             yes      3.0       no        furnished
# 2              no              no      NaN      yes   semi-furnished
# 3              no             yes      3.0      yes        furnished
# 4              no             yes      2.0       no        furnished

# %%
dfEmpty.dropna(how = 'all' , inplace = True)

# %%
dfEmpty.isna().sum()
# Out:
# price               0
# area                0
# bedrooms            2
# bathrooms           0
# stories             4
# mainroad            0
# guestroom           4
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             2
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
dfEmpty["bedrooms"].value_counts()
# Out:
# bedrooms
# 3.0    300
# 2.0    135
# 4.0     94
# 5.0     10
# 6.0      2
# 1.0      2
# Name: count, dtype: int64

# %%
dfEmpty["bedrooms"].fillna(2)
# Out:
# 0      4.0
# 1      4.0
# 2      3.0
# 3      4.0
# 4      4.0
#       ...
# 540    2.0
# 541    3.0
# 542    2.0
# 543    3.0
# 544    3.0
# Name: bedrooms, Length: 545, dtype: float64

# %%
dfEmpty["bedrooms"].fillna(3)
# Out:
# 0      4.0
# 1      4.0
# 2      3.0
# 3      4.0
# 4      4.0
#       ...
# 540    2.0
# 541    3.0
# 542    2.0
# 543    3.0
# 544    3.0
# Name: bedrooms, Length: 545, dtype: float64

# %%
dfEmpty["bedrooms"].mode()
# Out:
# 0    3.0
# Name: bedrooms, dtype: float64

# %%
dfEmpty["bedrooms"].fillna(dfEmpty["bedrooms"].mode())
# Out:
# 0      4.0
# 1      4.0
# 2      3.0
# 3      4.0
# 4      4.0
#       ...
# 540    2.0
# 541    3.0
# 542    2.0
# 543    3.0
# 544    3.0
# Name: bedrooms, Length: 545, dtype: float64

# %%
# end
